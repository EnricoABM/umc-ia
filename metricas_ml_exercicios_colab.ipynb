# %% [markdown]
# <a href="https://colab.research.google.com/github/EnricoABM/umc-ia/blob/main/metricas_ml_exercicios_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Métricas em Machine Learning — Guia e Exercícios (Somente Enunciados, Fórmulas Compatíveis com Google Colab)
#
# Este notebook apresenta explicações detalhadas sobre as principais métricas de avaliação de desempenho em **classificação binária**, seguidas por **20 exercícios práticos** com matrizes de confusão para cálculo manual.
#
# As fórmulas estão formatadas para renderização automática no **Google Colab** e em qualquer ambiente Jupyter compatível com **MathJax**.
#
# ---

# %% [markdown]
# ## 1. Estrutura da Matriz de Confusão
#
# Para classificação binária:
#
# |                     | Predito Positivo | Predito Negativo |
# |---------------------|------------------|------------------|
# | **Real Positivo**   | **TP** (Verdadeiro Positivo) | **FN** (Falso Negativo) |
# | **Real Negativo**   | **FP** (Falso Positivo) | **TN** (Verdadeiro Negativo) |
#
# Esses quatro elementos são a base para todas as métricas apresentadas a seguir.

# %% [markdown]
# ## 2. Métricas Fundamentais (com Fórmulas LaTeX Renderizadas)

# %% [markdown]
# ### Acurácia (Accuracy)
# **O que é:** Proporção total de classificações corretas.
# **Fórmula:**
# $$Accuracy = \frac{TP + TN}{TP + TN + FP + FN}$$
#
# **O que mede:** Percentual geral de acertos do modelo.
# **Benefícios:** Útil quando há **classes balanceadas**.
# **Limitações:** Enganosa em bases desbalanceadas (pode parecer alta mesmo com baixo recall).
#
# ---

# %% [markdown]
# ### Taxa de Erro (Error Rate)
# **O que é:** Proporção de classificações incorretas.
# **Fórmula:**
# $$Error = \frac{FP + FN}{TP + TN + FP + FN} = 1 - Accuracy$$
#
# **O que mede:** Mede diretamente o erro global.
# **Benefícios:** Complementa a acurácia.
# **Limitações:** Não distingue o tipo de erro (FP ou FN).
#
# ---

# %% [markdown]
# ### Precisão (Precision ou PPV)
# **O que é:** Proporção de predições positivas que são realmente positivas.
# **Fórmula:**
# $$Precision = \frac{TP}{TP + FP}$$
#
# **O que mede:** Avalia a confiabilidade das predições positivas.
# **Benefícios:** Importante quando **falsos positivos** são graves.
# **Limitações:** Ignora falsos negativos.
#
# > O quanto do que ele diz ser verdadeiro é realmente verdadeiro (Falar a verdade)
# ---

# %% [markdown]
# ### Sensibilidade (Recall ou TPR)
# **O que é:** Proporção de positivos reais identificados corretamente.
# **Fórmula:**
# $$Recall = \frac{TP}{TP + FN}$$
#
# **O que mede:** Capacidade do modelo em encontrar casos positivos.
# **Benefícios:** Essencial quando **falsos negativos** são críticos.
# **Limitações:** Pode gerar muitos falsos positivos se maximizada isoladamente.
#
# > O quanto dos casos verdadeiros ele disse ser verdadeiro (Não deixar na mão)
# ---

# %% [markdown]
# ### Especificidade (Specificity ou TNR)
# **O que é:** Proporção de negativos reais identificados corretamente.
# **Fórmula:**
# $$Specificity = \frac{TN}{TN + FP}$$
#
# **O que mede:** Capacidade de reconhecer verdadeiros negativos.
# **Benefícios:** Importante quando **falsos positivos** são custosos.
# **Limitações:** Baixa especificidade gera excesso de alarmes falsos.
#
# > O quanto dos casos negativos ele disse ser negativos (Não deixar na mão)
# ---

# %% [markdown]
# ### F1-Score
# **O que é:** Média harmônica entre precisão e sensibilidade.
# **Fórmula:**
# $$F1 = 2 \times \frac{Precision \times Recall}{Precision + Recall}$$
#
# **O que mede:** Equilibra precisão e recall.
# **Benefícios:** Boa para bases desbalanceadas.
# **Limitações:** Não considera verdadeiros negativos (TN).
#
# ---

# %% [markdown]
# ### Acurácia Balanceada (Balanced Accuracy)
# **O que é:** Média entre sensibilidade e especificidade.
# **Fórmula:**
# $$Balanced\ Accuracy = \frac{Recall + Specificity}{2}$$
#
# **O que mede:** Corrige viés de classe dominante.
# **Benefícios:** Mantém interpretação intuitiva (0–1).
# **Limitações:** Menos detalhada que métricas compostas como MCC.
#
# > Média do quanto não deixa na mão - Positivos e Negativos
# ---

# %% [markdown]
# ### Coeficiente de Correlação de Matthews (MCC)
# **O que é:** Correlação entre predições e valores reais.
# **Fórmula:**
# $$MCC = \frac{TP \times TN - FP \times FN}{\sqrt{(TP+FP)(TP+FN)(TN+FP)(TN+FN)}}$$
#
# **O que mede:** Robusta mesmo em bases desbalanceadas.
# **Benefícios:** Ideal em contextos biomédicos e bioinformáticos.
# **Limitações:** Interpretação matemática menos intuitiva.
#
# ---

# %% [markdown]
# ## 3. Exercícios — Aplicação das Métricas
#
# A seguir, são apresentadas **20 situações realistas** com matrizes de confusão.
# Em cada caso, calcule manualmente todas as métricas apresentadas acima:
#
# - Accuracy
# - Error Rate
# - Precision (PPV)
# - Recall (TPR)
# - Specificity (TNR)
# - F1-score
# - Balanced Accuracy
# - MCC
#
# > **Importante:** Use sempre as mesmas fórmulas. Apresente os cálculos detalhados e interprete clinicamente os resultados.

# %% [markdown]
# ## 4. Exercícios — Enunciados

# %%
from math import sqrt

# Acurácia
def acuracia(tp, tn, fp, fn):
    acc = (tp + tn) / (tp + tn + fp + fn)
    return acc

# Taxa de Erro
def taxa_erro(tp, tn, fp, fn):
    err = (fp + fn) / (tp + tn + fp + fn)
    return err

# Precisão
def precisao(tp, fp):
    prec = tp / (tp + fp)
    return prec

# Sensibilidade
def sensibilidade(tp, fn):
    rec = tp / (tp + fn)
    return rec

# Especificidade
def especificidade(tn, fp):
    esp = tn / (tn + fp)
    return esp

# F1-Score
def f1_score(tp, fn, fp):
    pre = precisao(tp, fp)
    rec = sensibilidade(tp, fn)
    f1 = 2 * ((pre * rec) / (pre + rec))
    return f1

# Acurácia Balanceada
def acuracia_balanceada(tp, tn, fp, fn):
    rec = sensibilidade(tp, fn)
    esp = especificidade(tn, fp)
    acc_b = (rec + esp) / 2
    return acc_b

# Coenficiente de Correlação de Matthews
def mcc(tp, tn, fp, fn):
    aux1 = (tp * tn) - (fp * fn)
    aux2 = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    result = aux1 / sqrt(aux2)
    return result

# Função para calcular todas as métricas
def calcular_metricas(tp, tn, fp, fn):
    metricas = {}
    metricas['Acuracia'] = acuracia(tp, tn, fp, fn)
    metricas['Taxa de Erro'] = taxa_erro(tp, tn, fp, fn)
    metricas['Precisao'] = precisao(tp, fp)
    metricas['Sensibilidade'] = sensibilidade(tp, fn)
    metricas['Especificidade'] = especificidade(tn, fp)
    metricas['F1 Score'] = f1_score(tp, fn, fp)
    metricas['Acuracia Balanceda'] = acuracia_balanceada(tp, tn, fp, fn)
    metricas['MCC'] = mcc(tp, tn, fp, fn)
    return metricas

# Função para exibir as métricas em uma tabela
def printar_tabela(metricas):
    print(f"{'Metrica':<18} | {'Valor'}")
    print('-' * 27)
    for metrica, valor in metricas.items():
        print(f'{metrica:<18} | {valor:<0.4f}')

# %% [markdown]
# ### Exercício 01 — BioScan (mamografia)
#
# **Contexto:** Detecção de câncer de mama em lâminas histológicas digitais.
#
# **Matriz de Confusão:**
# - **TP** = 160
# - **FN** = 40
# - **FP** = 30
# - **TN** = 170
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 160.0
fn = 40.0
fp = 30.0
tn = 170.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8250
# Taxa de Erro       | 0.1750
# Precisao           | 0.8421
# Sensibilidade      | 0.8000
# Especificidade     | 0.8500
# F1 Score           | 0.8205
# Acuracia Balanceda | 0.8250
# MCC                | 0.6508

# %% [markdown]
# Falso Positivo - Não tinha cancer, mas predizeu cancer. Impacto emocional e financeiro no paciente, levando a exames que comprovariam falso.
#
# Falso Negativo - Tinha cancer, mas predizeu que não. Impacto a longo prazo, cancer pode ser descoberto só depois de meses e anos, extremamente preocupante.
#
# Métrica mais relavante = Sensibilidade, falsos negativos são castrastróficos nesse caso.

# %% [markdown]
# >

# %% [markdown]
# ### Exercício 02 — NeuroCheck (EEG-epilepsia)
#
# **Contexto:** Identificação de crises epilépticas em EEG multicanal.
#
# **Matriz de Confusão:**
# - **TP** = 85
# - **FN** = 15
# - **FP** = 20
# - **TN** = 180
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 85.0
fn = 15.0
fp = 20.0
tn = 180.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8833
# Taxa de Erro       | 0.1167
# Precisao           | 0.8095
# Sensibilidade      | 0.8500
# Especificidade     | 0.9000
# F1 Score           | 0.8293
# Acuracia Balanceda | 0.8750
# MCC                | 0.7412

# %% [markdown]
# Falsos Negativos (15) - 15 Crises não foram alertadas pelo modelo, podendo que esses tenham complicações e danos piores.
#
# Falsos Positivos (20) - 20 Alarmes falsos, teria a mobilização de recursos e o estresse para socorrer, porém nenhum dano seria causado.
#
# Métrica mais relevante: Recall, evitar que crises não passem despercebidas

# %% [markdown]
# ### Exercício 03 — LaBiOmicS (bactéria patogênica)
#
# **Contexto:** Classificação genômica de cepas bacterianas.
#
# **Matriz de Confusão:**
# - **TP** = 70
# - **FN** = 10
# - **FP** = 25
# - **TN** = 95
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 70.0
fn = 10.0
fp = 25.0
tn = 95.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8250
# Taxa de Erro       | 0.1750
# Precisao           | 0.7368
# Sensibilidade      | 0.8750
# Especificidade     | 0.7917
# F1 Score           | 0.8000
# Acuracia Balanceda | 0.8333
# MCC                | 0.6540

# %%
Falsos Negativos (10) - 10 Bactérias patogênicas foram identificadas como não patogênicas, impacto fica a cargo da finalidade das bacterias. No caso, 10 bactérias entraram nas amostras de teste.

Falsos Positivos (25) - 25 Bactérias não patogênicas foram identificas como patogênicas, impacto fica a cargo da finalidade das bacterias. No caso, 25 bactérias ficaram fora do estudo, o que pode impactar o estudo.

Métrica mais relevante: MCC, baseado ao contexto que se aplica

# %% [markdown]
# ### Exercício 04 — VetSense (cardiopatia canina)
#
# **Contexto:** Diagnóstico de doença cardíaca em cães.
#
# **Matriz de Confusão:**
# - **TP** = 45
# - **FN** = 15
# - **FP** = 20
# - **TN** = 120
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 45.0
fn = 15.0
fp = 20.0
tn = 120.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8250
# Taxa de Erro       | 0.1750
# Precisao           | 0.6923
# Sensibilidade      | 0.7500
# Especificidade     | 0.8571
# F1 Score           | 0.7200
# Acuracia Balanceda | 0.8036
# MCC                | 0.5940

# %% [markdown]
# Falsos Negativos (15) - 15 Cães que não tiveram o diagnóstico de doença cardiáca. Podendo levar a complicações futuras.
#
# Falsos Positivos (20) - 20 Cães tiveram o diagnóstico positivo, porém não havia doença. Custo com o tratamento, porém sem danos graves.
#
# Métrica mais relevante: Recall, para não passar cães doentes como saudáveis.

# %% [markdown]
# ### Exercício 05 — EcoAI (desmatamento)
#
# **Contexto:** Detecção de áreas com risco de desmatamento via satélite.
#
# **Matriz de Confusão:**
# - **TP** = 210
# - **FN** = 40
# - **FP** = 60
# - **TN** = 290
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 210.0
fn = 40.0
fp = 60.0
tn = 290.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8333
# Taxa de Erro       | 0.1667
# Precisao           | 0.7778
# Sensibilidade      | 0.8400
# Especificidade     | 0.8286
# F1 Score           | 0.8077
# Acuracia Balanceda | 0.8343
# MCC                | 0.6625

# %% [markdown]
# Falsos Negativos (40) - 40 Áreas não foram protegidas contra o desmatamento. Impacto ambiental
#
# Falsos Positivos (60) - 60 Áreas foram protegidas sem necessidade. Custoso
#
# Métrica mais relevante: Especificidade, evitar custos com áreas desnecessárias.

# %% [markdown]
# ### Exercício 06 — FinGuard (fraude)
#
# **Contexto:** Detecção de transações financeiras fraudulentas.
#
# **Matriz de Confusão:**
# - **TP** = 45
# - **FN** = 5
# - **FP** = 25
# - **TN** = 425
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 45.0
fn = 5.0
fp = 25.0
tn = 425.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.9400
# Taxa de Erro       | 0.0600
# Precisao           | 0.6429
# Sensibilidade      | 0.9000
# Especificidade     | 0.9444
# F1 Score           | 0.7500
# Acuracia Balanceda | 0.9222
# MCC                | 0.7301

# %% [markdown]
# Falsos Negativos (5) - 5 Transações fradulentas foram permitidas. Impacto financeiro
#
# Falsos Positivos (25) - 25 Transações legitímas foram barradas. Incoveniência.
#
# Métrica mais relevante: Recall, para não passar transações fradulentas

# %% [markdown]
# ### Exercício 07 — CovidScan (RX tórax)
#
# **Contexto:** Predição de COVID-19 a partir de imagens de tórax.
#
# **Matriz de Confusão:**
# - **TP** = 420
# - **FN** = 80
# - **FP** = 100
# - **TN** = 400
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 420.0
fn = 80.0
fp = 100.0
tn = 400.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-693804942.py in <cell line: 0>()
#       4 tn = 400.0
#       5
# ----> 6 metricas = calcular_metricas(tp, tn, fp, fn)
#       7 printar_tabela(metricas)
#
# NameError: name 'calcular_metricas' is not defined

# %% [markdown]
# Falsos Negativos (80) - 80 Paciente possuiam covid e foram diagnosticados como saudáveis. Sáude dos pacientes, pode ser letal para alguns
#
# Falsos Positivos (100) - 100 Pacientes não possuiam covid e foram diagnosticados com covid. Incoveniência.
#
# Métrica mais relevante: Precisão, para ter mais exatidão com o diagnostico dos pacientes.

# %% [markdown]
# ### Exercício 08 — Onco-Path (biópsia)
#
# **Contexto:** Classificação de biópsias em malignas vs benignas.
#
# **Matriz de Confusão:**
# - **TP** = 52
# - **FN** = 18
# - **FP** = 12
# - **TN** = 118
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 52.0
fn = 18.0
fp = 12.0
tn = 118.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8500
# Taxa de Erro       | 0.1500
# Precisao           | 0.8125
# Sensibilidade      | 0.7429
# Especificidade     | 0.9077
# F1 Score           | 0.7761
# Acuracia Balanceda | 0.8253
# MCC                | 0.6652

# %% [markdown]
# Falsos Negativos (18) - 18 Amostras foram classificadas como benignas sendo malignas. Risco para os pacientes que não foram diagnosticados.
#
# Falsos Positivos (12) - 12 Amostras foram classificadas como malignas sendo benignas. Incoveniente enorme dos pacientes que tiveram que passar por quimioterapia e radioterapia.
#
# Métrica mais relevante: Acurácia, ter mais exatidão em todas as previsões.

# %% [markdown]
# ### Exercício 09 — SepsisAlert (UTI)
#
# **Contexto:** Alerta precoce de sepse em UTI.
#
# **Matriz de Confusão:**
# - **TP** = 38
# - **FN** = 7
# - **FP** = 22
# - **TN** = 133
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 38.0
fn = 7.0
fp = 22.0
tn = 133.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8550
# Taxa de Erro       | 0.1450
# Precisao           | 0.6333
# Sensibilidade      | 0.8444
# Especificidade     | 0.8581
# F1 Score           | 0.7238
# Acuracia Balanceda | 0.8513
# MCC                | 0.6402

# %% [markdown]
# Falsos Negativos (7) - 7 Casos não foram alarmados, piora na condição do paciente.
#
# Falsos Positivos (22) - 22 Casos foram alarmados, porém eram falsos. Incoviente, desgaste da equipe.
#
# Métrica mais relevante: Recall, garantir que casos reais sejam alarmados.

# %% [markdown]
# ### Exercício 10 — NeoScreen (neonatal)
#
# **Contexto:** Triagem neonatal para doença metabólica rara.
#
# **Matriz de Confusão:**
# - **TP** = 61
# - **FN** = 9
# - **FP** = 15
# - **TN** = 215
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 61.0
fn = 9.0
fp = 15.0
tn = 215.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.9200
# Taxa de Erro       | 0.0800
# Precisao           | 0.8026
# Sensibilidade      | 0.8714
# Especificidade     | 0.9348
# F1 Score           | 0.8356
# Acuracia Balanceda | 0.9031
# MCC                | 0.7840

# %% [markdown]
# Falsos Negativos (9) - 9 Pacientes não foram diagnosticados, levando descobrimento tardio da doença. Gera complicações durante a juventude e perdas severas dependendo da gravidade.
#
# Falsos Positivos (15) - 15 Pacientes foram diagnosticados sem terem a doença. Esforço e Recursos com tratamento ao longo de anos desnecessário.
#
# Métrica mais relevante: Especificidade, garantir que casos falsos positivos sejam reduzidos.

# %% [markdown]
# ### Exercício 11 — DermAI (lesões cutâneas)
#
# **Contexto:** Classificação de lesões malignas/benignas.
#
# **Matriz de Confusão:**
# - **TP** = 92
# - **FN** = 28
# - **FP** = 35
# - **TN** = 245
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 92.0
fn = 28.0
fp = 35.0
tn = 245.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8425
# Taxa de Erro       | 0.1575
# Precisao           | 0.7244
# Sensibilidade      | 0.7667
# Especificidade     | 0.8750
# F1 Score           | 0.7449
# Acuracia Balanceda | 0.8208
# MCC                | 0.6317

# %% [markdown]
# Falsos Negativos (28) - 28 Casos malignos classificados como benignos. Complicações e danos potencialmente graves posteriormente.
#
# Falsos Positivos (35) - 35 Casos benignos classificados como malignos. Incoveniente e problemas relacionados ao tratamento.
#
# Métrica mais relevante: Acurácia, garantir maior taxa de acertos, reduzindo o número total de casos falsos.

# %% [markdown]
# ### Exercício 12 — CardioRisk (ECG)
#
# **Contexto:** Risco de arritmia baseado em ECG.
#
# **Matriz de Confusão:**
# - **TP** = 74
# - **FN** = 26
# - **FP** = 18
# - **TN** = 182
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 74.0
fn = 26.0
fp = 18.0
tn = 182.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8533
# Taxa de Erro       | 0.1467
# Precisao           | 0.8043
# Sensibilidade      | 0.7400
# Especificidade     | 0.9100
# F1 Score           | 0.7708
# Acuracia Balanceda | 0.8250
# MCC                | 0.6645

# %% [markdown]
# Falsos Negativos (26) - 26 Casos não foram alarmados, levando agravamento da doença.
#
# Falsos Positivos (18) - 18 Casos foram alertados sem necessidade, uso desnecessário de recursos.
#
# Métrica mais relevante: Recall, evitar que casos reais não sejam notificados.

# %% [markdown]
# ### Exercício 13 — TB-Scan (tuberculose)
#
# **Contexto:** Diagnóstico de tuberculose por radiografia.
#
# **Matriz de Confusão:**
# - **TP** = 58
# - **FN** = 12
# - **FP** = 30
# - **TN** = 300
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 58.0
fn = 12.0
fp = 30.0
tn = 300.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8950
# Taxa de Erro       | 0.1050
# Precisao           | 0.6591
# Sensibilidade      | 0.8286
# Especificidade     | 0.9091
# F1 Score           | 0.7342
# Acuracia Balanceda | 0.8688
# MCC                | 0.6766

# %% [markdown]
# Falsos Negativos (12) - 12 Casos não foram alarmados, levando ao agravamento da doença.
#
# Falsos Positivos (30) - 30 Casos foram alarmados desnecessariamente, levando ao uso de recursos e incoveniência ao paciente.
#
# Métrica mais relevante: Recall, para evitar que pacientes sejam diagnosticados erroneamente.

# %% [markdown]
# ### Exercício 14 — MycoDetect (infecção fúngica)
#
# **Contexto:** Detecção de infecção fúngica invasiva.
#
# **Matriz de Confusão:**
# - **TP** = 33
# - **FN** = 17
# - **FP** = 11
# - **TN** = 139
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 33.0
fn = 17.0
fp = 11.0
tn = 139.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8600
# Taxa de Erro       | 0.1400
# Precisao           | 0.7500
# Sensibilidade      | 0.6600
# Especificidade     | 0.9267
# F1 Score           | 0.7021
# Acuracia Balanceda | 0.7933
# MCC                | 0.6132

# %% [markdown]
# Falsos Negativos (17) - 17 Casos não foram diagnosticados corretamente, o que pode levar ao agravamento da doença.
#
# Falsos Positivos (11) - 11 Casos diagnosticados como positivo sem terem a doença. Incoveniente pelo tratamento.
#
# Métrica mais relevante: Recall, evitar que pacientes doentes não sejam diagnosticados corretamente.

# %% [markdown]
# ### Exercício 15 — GenoPath (variantes patogênicas)
#
# **Contexto:** Predição de patogenicidade de variantes genéticas.
#
# **Matriz de Confusão:**
# - **TP** = 28
# - **FN** = 6
# - **FP** = 9
# - **TN** = 257
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 28.0
fn = 6.0
fp = 9.0
tn = 257.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.9500
# Taxa de Erro       | 0.0500
# Precisao           | 0.7568
# Sensibilidade      | 0.8235
# Especificidade     | 0.9662
# F1 Score           | 0.7887
# Acuracia Balanceda | 0.8948
# MCC                | 0.7613

# %% [markdown]
# Falsos Negativos (6) - 6 Casos foram diagnosticados corretamente. Agravamento de doenças sem acompanhamento.
#
# Falsos Positivos (9) - 9 Casos foram diagnosticados como positivos sem ter nenhuma doença. Gasto com recursos para tratamento e incoviência com qualquer tratamento severo.
#
# Métrica mais relevante: Recall, evitar que pacientes doentes sejam diagnosticados como saudáveis.

# %% [markdown]
# ### Exercício 16 — StrokeGuard (AVC)
#
# **Contexto:** Detecção de AVC isquêmico em pronto atendimento.
#
# **Matriz de Confusão:**
# - **TP** = 66
# - **FN** = 14
# - **FP** = 24
# - **TN** = 196
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 66.0
fn = 14.0
fp = 24.0
tn = 196.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8733
# Taxa de Erro       | 0.1267
# Precisao           | 0.7333
# Sensibilidade      | 0.8250
# Especificidade     | 0.8909
# F1 Score           | 0.7765
# Acuracia Balanceda | 0.8580
# MCC                | 0.6908

# %% [markdown]
# Falsos Negativos (14) - 14 Pacientes tiveram AVC e não foram socorridos, risco de morte.
#
# Falsos Positivos (24) - 24 Pacientes foram tratados sem necessidade, enorme esforço e recurso gasto para o tratamento.
#
# Métrica mais relevante: Recall, evitar que pacientes não sejam socorridos devidamente.

# %% [markdown]
# ### Exercício 17 — HemoAI (anemia)
#
# **Contexto:** Diagnóstico automatizado de anemia.
#
# **Matriz de Confusão:**
# - **TP** = 81
# - **FN** = 19
# - **FP** = 27
# - **TN** = 273
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 81.0
fn = 19.0
fp = 27.0
tn = 273.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8850
# Taxa de Erro       | 0.1150
# Precisao           | 0.7500
# Sensibilidade      | 0.8100
# Especificidade     | 0.9100
# F1 Score           | 0.7788
# Acuracia Balanceda | 0.8600
# MCC                | 0.7022

# %% [markdown]
# Falsos Negativos (19) - 19 Pacientes que possuem a doença não foram diagnosticados com a doença. Complicações de sáude devido a falta de cuidado e tratamento.
#
# Falsos Positivos (27) - 27 Pacientes que não possuem a doença foram diagnosticados com a doença. Uso desnecessário de recurso e tratamento.
#
# Métrica mais relevante: Precisão, garantir mais precisão nos acertos e miticar casos falsos.

# %% [markdown]
# ### Exercício 18 — AllerSense (anafilaxia)
#
# **Contexto:** Alerta de risco de anafilaxia em ambiente hospitalar.
#
# **Matriz de Confusão:**
# - **TP** = 25
# - **FN** = 5
# - **FP** = 20
# - **TN** = 350
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 25.0
fn = 5.0
fp = 20.0
tn = 350.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.9375
# Taxa de Erro       | 0.0625
# Precisao           | 0.5556
# Sensibilidade      | 0.8333
# Especificidade     | 0.9459
# F1 Score           | 0.6667
# Acuracia Balanceda | 0.8896
# MCC                | 0.6496

# %% [markdown]
# Falsos Negativos (5) - 5 Pacientes não foram alarmados e tiveram complicações.
#
# Falsos Positivos (20) - 20 Pacientes foram alarmados e estavam saudáveis. Gasto de recurso
#
# Métrica mais relevante: Especificidade, garantir que casos falsos classificados como verdadeiro levem mais recursos.

# %% [markdown]
# ### Exercício 19 — ICU-Mortality (mortalidade 48h)
#
# **Contexto:** Predição de alta mortalidade em UTI nas próximas 48h.
#
# **Matriz de Confusão:**
# - **TP** = 49
# - **FN** = 11
# - **FP** = 29
# - **TN** = 311
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 49.0
fn = 11.0
fp = 29.0
tn = 311.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.9000
# Taxa de Erro       | 0.1000
# Precisao           | 0.6282
# Sensibilidade      | 0.8167
# Especificidade     | 0.9147
# F1 Score           | 0.7101
# Acuracia Balanceda | 0.8657
# MCC                | 0.6591

# %% [markdown]
# Falsos Negativos (11) - 11 Pacientes estavam com alto risco de morte e foram classificados como baixo. Risco de morte do paciente.
#
# Falsos Positivos (29) - 29 Pacientes estavam com baixo risco e foram classficiados como alto. Alocação excessiva de recursos.
#
# Métrica mais relevante: Recall, evitar que pacientes com alto risco sejam ignorados.

# %% [markdown]
# ### Exercício 20 — EndoDiag (endometriose)
#
# **Contexto:** Predição de endometriose combinando sinais clínicos e imagem.
#
# **Matriz de Confusão:**
# - **TP** = 72
# - **FN** = 18
# - **FP** = 22
# - **TN** = 188
#
# **Tarefas:**
# 1. Calcule manualmente, sem bibliotecas, todas as métricas apresentadas.
# 2. Interprete os resultados (impacto de FP e FN) e justifique qual métrica deve ser priorizada neste contexto.
#
# ---

# %%
tp = 72.0
fn = 18.0
fp = 22.0
tn = 188.0

metricas = calcular_metricas(tp, tn, fp, fn)
printar_tabela(metricas)
# Out:
# Metrica            | Valor
# ---------------------------
# Acuracia           | 0.8667
# Taxa de Erro       | 0.1333
# Precisao           | 0.7660
# Sensibilidade      | 0.8000
# Especificidade     | 0.8952
# F1 Score           | 0.7826
# Acuracia Balanceda | 0.8476
# MCC                | 0.6869

# %% [markdown]
# Falsos Negativos (18) - 18 Pacientes foram classificados como saudáveis, o que leva ao agravamento da doença.
#
# Falsos Positivos (22) - 22 Pacientes que foram classificados como doentes. Incoviencia por tratamento desnecessário.
#
# Métrica mais relevante: Recall, evitar que pacientes sejam doentes sejam classificados como saudáveis.
